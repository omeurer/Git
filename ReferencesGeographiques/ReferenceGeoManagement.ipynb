# %% [markdown]
# # Librairies

# %%
import pandas as pd

# %% [markdown]
# # Iris

# %%
refIris=pd.read_excel("reference_IRIS.xlsx",header=5)

# %%
refIrisClean=refIris.rename(columns={"DEP":"numDep"})

# %%
refIrisClean
# Out:
#        CODE_IRIS                                      LIB_IRIS TYP_IRIS  \
# 0      010010000  L'Abergement-Clémenciat (commune non irisée)        Z
# 1      010020000    L'Abergement-de-Varey (commune non irisée)        Z
# 2      010040101             Les Pérouses-Triangle d'Activités        H
# 3      010040102                                 Longeray-Gare        H
# 4      010040201                Centre-Saint-Germain-Vareilles        H
# ...          ...                                           ...      ...
# 49401  976170301                                 Combani Ouest        H
# 49402  976170302                                   Combani Est        H
# 49403  976170303                            Tsingoni-Sud Épars        D
# 49404  976170304                           Tsingoni-Nord Épars        D
# 49405  976170400                                      Miréréni        H
#
#       GRD_QUART DEPCOM                   LIBCOM UU2020  REG numDep
# ...

# %%
refIrisClean.to_csv('/Users/oscarmeurer/iCloud Drive (archive) - 1/Documentss/Pour Disque Dur (last 3 decembre 2021)/Centrale Lille /G3/Croix Rouge Française/VsCode/Git/ReferencesGeographiques/ReferenceClean/iris.csv')

# %% [markdown]
# # Departements

# %%
dep=pd.read_csv('departement.csv',header=0).drop(columns=['id','del1','del2','del3'])

# %%
dep
# Out:
#     numDep                   nomDep
# 0       01                      Ain
# 1       02                    Aisne
# 2       03                   Allier
# 3       05             Hautes-Alpes
# 4       04  Alpes-de-Haute-Provence
# ..     ...                      ...
# 96     976                  Mayotte
# 97     971               Guadeloupe
# 98     973                   Guyane
# 99     972               Martinique
# 100    974                  Réunion
#
# [101 rows x 2 columns]

# %% [markdown]
# # Departements & iris

# %%
refIrisClean
# Out:
#        CODE_IRIS                                      LIB_IRIS TYP_IRIS  \
# 0      010010000  L'Abergement-Clémenciat (commune non irisée)        Z
# 1      010020000    L'Abergement-de-Varey (commune non irisée)        Z
# 2      010040101             Les Pérouses-Triangle d'Activités        H
# 3      010040102                                 Longeray-Gare        H
# 4      010040201                Centre-Saint-Germain-Vareilles        H
# ...          ...                                           ...      ...
# 49401  976170301                                 Combani Ouest        H
# 49402  976170302                                   Combani Est        H
# 49403  976170303                            Tsingoni-Sud Épars        D
# 49404  976170304                           Tsingoni-Nord Épars        D
# 49405  976170400                                      Miréréni        H
#
#       GRD_QUART DEPCOM                   LIBCOM UU2020  REG numDep
# ...

# %%
irisDep=refIrisClean.merge(dep)

# %%
irisDep
# Out:
#        CODE_IRIS                                      LIB_IRIS TYP_IRIS  \
# 0      010010000  L'Abergement-Clémenciat (commune non irisée)        Z
# 1      010020000    L'Abergement-de-Varey (commune non irisée)        Z
# 2      010040101             Les Pérouses-Triangle d'Activités        H
# 3      010040102                                 Longeray-Gare        H
# 4      010040201                Centre-Saint-Germain-Vareilles        H
# ...          ...                                           ...      ...
# 48997  976170301                                 Combani Ouest        H
# 48998  976170302                                   Combani Est        H
# 48999  976170303                            Tsingoni-Sud Épars        D
# 49000  976170304                           Tsingoni-Nord Épars        D
# 49001  976170400                                      Miréréni        H
#
#       GRD_QUART DEPCOM                   LIBCOM UU2020  REG numDep   nomDep
# ...
