# %%
import pandas as pd
import geopandas as gpd
import math
import numpy as np

# %%
communes=gpd.gpd.read_file('iris/communes-20190101/communes-20190101.json')

# %%
communes
# Out:
#        insee                       nom                     wikipedia  surf_ha  \
# 0      97223              Saint-Esprit  fr:Saint-Esprit (Martinique)     2318
# 1      97233             Le Morne-Vert              fr:Le Morne-Vert     1325
# 2      97208         Fonds-Saint-Denis          fr:Fonds-Saint-Denis     2374
# 3      97224              Saint-Joseph  fr:Saint-Joseph (Martinique)     4324
# 4      97212                Gros-Morne                 fr:Gros-Morne     4601
# ...      ...                       ...                           ...      ...
# 34977  95219                    Ermont                     fr:Ermont      416
# 34978  78172  Conflans-Sainte-Honorine   fr:Conflans-Sainte-Honorine      988
# 34979  78005                   Achères         fr:Achères (Yvelines)      972
# 34980  78358          Maisons-Laffitte           fr:Maisons-Laffitte      693
# 34981  95572       Saint-Ouen-l'Aumône        fr:Saint-Ouen-l'Aumône     1401
#
# ...
